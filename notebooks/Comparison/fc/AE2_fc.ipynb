# %% [markdown]
# <a href="https://colab.research.google.com/github/VMBoehm/SDSS_PAE/blob/main/LSTM_AE.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training the Conditional Auto-Encoder with the settings obtained from Optimization

# %%
import tensorflow as tf
tf.__version__
tf.config.list_physical_devices('GPU')


import numpy as np
import scipy
import matplotlib.pyplot as plt
import os
import logging
import sys
from sklearn import preprocessing
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Layer, Reshape, LeakyReLU, BatchNormalization, Dense, Flatten, Input,Dropout
import random
import numpy as np
import pickle

# %%
SMALL_SIZE =  14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
RUN             = '1'

seeds           = {'1':5123, '2':879, '3':9981, '4': 20075, '5': 66, '6': 276, '7': 936664}

conditional     = False
cond_on         = 'type'

root_model_data = '/global/cscratch1/sd/vboehm/Datasets/sdss/by_model/'
root_models     = '/global/cscratch1/sd/vboehm/Models/SDSS_AE/'
root_encoded    = '/global/cscratch1/sd/vboehm/Datasets/encoded/sdss/'
root_decoded    = '/global/cscratch1/sd/vboehm/Datasets/decoded/sdss/'


wlmin, wlmax    = (3388,8318)
fixed_num_bins  = 1000
min_SN          = 50
min_z           = 0.05
max_z           = 0.36
label           = 'galaxies_quasars_bins%d_wl%d-%d'%(fixed_num_bins,wlmin,wlmax)
label_          = label+'_minz%s_maxz%s_minSN%d'%(str(int(min_z*100)).zfill(3),str(int(max_z*100)).zfill(3),min_SN)
label_2         = label_+'_10_fully_connected_mean_div'


plotpath        = '/global/homes/v/vboehm/codes/SDSS_PAE/figures'


if conditional:
    label_2='conditional_%s'%cond_on+label_2
    
data_path       = '/global/cscratch1/sd/vboehm/SDSSOutlier/fc'

# %%
tf.__version__
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
train,valid = np.load(os.path.join(data_path,'decoded_fc.npy'), allow_pickle=True)

# %%
len(valid)
# Out:
# 139642

# %%
valid_ = pickle.load(open(os.path.join(root_model_data,'SDSS_DR16_preprocessed_valid_labeled.pkl'),'rb'))

# %%
len(valid_['spec'])
# Out:
# 139642

# %%
os.path.join(root_models,'decoder_%s_run%s_new'%(label_2, RUN))
# Out:
# '/global/cscratch1/sd/vboehm/Models/SDSS_AE/decoder_galaxies_quasars_bins1000_wl3388-8318_minz005_maxz036_minSN50_10_fully_connected_mean_div_run1_new'

# %%
path = os.path.join(root_models,'encoder_%s_run%s_new'%(label_2, RUN))
encoder = tf.keras.models.load_model(path)
path = os.path.join(root_models,'decoder_%s_run%s_new'%(label_2, RUN))
decoder = tf.keras.models.load_model(path)
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.

# %%
encoder.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 1000)              0
# _________________________________________________________________
# dense (Dense)                (None, 1000)              1001000
# _________________________________________________________________
# leaky_re_lu (LeakyReLU)      (None, 1000)              0
# _________________________________________________________________
# reshape (Reshape)            (None, 1000, 1)           0
# _________________________________________________________________
# dropout (Dropout)            (None, 1000, 1)           0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1000)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 590)               590590
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 590)               0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 590, 1)            0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 590)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5910
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 10, 1)             0
# =================================================================
# Total params: 1,597,500
# Trainable params: 1,597,500
# Non-trainable params: 0
# _________________________________________________________________

# %%
decoder.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# reshape_3 (Reshape)          multiple                  0
# _________________________________________________________________
# flatten_3 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_3 (Dense)              multiple                  6490
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# reshape_4 (Reshape)          multiple                  0
# _________________________________________________________________
# flatten_4 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_4 (Dense)              multiple                  591000
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    multiple                  0
# _________________________________________________________________
# reshape_5 (Reshape)          multiple                  0
# _________________________________________________________________
# dropout_1 (Dropout)          multiple                  0
# _________________________________________________________________
# flatten_5 (Flatten)          multiple                  0
# _________________________________________________________________
# dense_5 (Dense)              multiple                  1001000
# =================================================================
# Total params: 1,598,490
# Trainable params: 1,598,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
input = Input((1000,1))

x = encoder(input)
x = decoder(x)

AE_2 = Model(input,x)

# %%
AE_2.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 1000, 1)]         0
# _________________________________________________________________
# sequential (Sequential)      (None, 10, 1)             1597500
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1000)              1598490
# =================================================================
# Total params: 3,195,990
# Trainable params: 3,195,990
# Non-trainable params: 0
# _________________________________________________________________

# %%
random.seed(seeds[RUN])
np.random.seed(seeds[RUN])
tf.random.set_seed(seeds[RUN])

# %%
opt = tf.keras.optimizers.Adam
lr  = learning_rate_fn = tf.keras.optimizers.schedules.PolynomialDecay(1e-3,20000,5e-5,power=0.5, cycle=False) 
AE_2.compile(loss='mean_squared_error', metrics='mean_squared_error', optimizer=opt(lr))

# %%
AE_2.fit(x=np.expand_dims(train,-1), y=np.expand_dims(train,-1),validation_data=(np.expand_dims(valid,-1),np.expand_dims(valid,-1)), epochs=55, batch_size=25)
# Out:
# Epoch 1/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 2.4183 - mean_squared_error: 2.4183 - val_loss: 0.1134 - val_mean_squared_error: 0.1134
# Epoch 2/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.1880 - mean_squared_error: 0.1880 - val_loss: 0.0284 - val_mean_squared_error: 0.0284
# Epoch 3/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0190 - mean_squared_error: 0.0190 - val_loss: 0.0112 - val_mean_squared_error: 0.0112
# Epoch 4/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0149 - mean_squared_error: 0.0149 - val_loss: 0.0099 - val_mean_squared_error: 0.0099
# Epoch 5/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0135 - mean_squared_error: 0.0135 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 6/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0098 - mean_squared_error: 0.0098 - val_loss: 0.0031 - val_mean_squared_error: 0.0031
# Epoch 7/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0075 - mean_squared_error: 0.0075 - val_loss: 0.0130 - val_mean_squared_error: 0.0130
# Epoch 8/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0104 - mean_squared_error: 0.0104 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 9/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0097 - mean_squared_error: 0.0097 - val_loss: 0.0032 - val_mean_squared_error: 0.0032
# Epoch 10/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0080 - mean_squared_error: 0.0080 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 11/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0129 - mean_squared_error: 0.0129 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 12/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0068 - mean_squared_error: 0.0068 - val_loss: 0.0021 - val_mean_squared_error: 0.0021
# Epoch 13/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0027 - val_mean_squared_error: 0.0027
# Epoch 14/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 15/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0091 - mean_squared_error: 0.0091 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 16/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0081 - mean_squared_error: 0.0081 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 17/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0143 - val_mean_squared_error: 0.0143
# Epoch 18/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0061 - mean_squared_error: 0.0061 - val_loss: 0.0033 - val_mean_squared_error: 0.0033
# Epoch 19/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 20/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0063 - mean_squared_error: 0.0063 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 21/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0071 - mean_squared_error: 0.0071 - val_loss: 0.0012 - val_mean_squared_error: 0.0012
# Epoch 22/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0022 - val_mean_squared_error: 0.0022
# Epoch 23/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0062 - mean_squared_error: 0.0062 - val_loss: 9.8652e-04 - val_mean_squared_error: 9.8652e-04
# Epoch 24/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0046 - mean_squared_error: 0.0046 - val_loss: 0.0060 - val_mean_squared_error: 0.0060
# Epoch 25/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 7.9174e-04 - val_mean_squared_error: 7.9174e-04
# Epoch 26/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0044 - mean_squared_error: 0.0044 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 27/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 28/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0025 - mean_squared_error: 0.0025 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 29/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0042 - val_mean_squared_error: 0.0042
# Epoch 30/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0108 - mean_squared_error: 0.0108 - val_loss: 7.5708e-04 - val_mean_squared_error: 7.5708e-04
# Epoch 31/55
# 8379/8379 [==============================] - 19s 2ms/step - loss: 0.0040 - mean_squared_error: 0.0040 - val_loss: 0.0010 - val_mean_squared_error: 0.0010
# Epoch 32/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0055 - mean_squared_error: 0.0055 - val_loss: 6.1560e-04 - val_mean_squared_error: 6.1560e-04
# Epoch 33/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0029 - mean_squared_error: 0.0029 - val_loss: 0.0041 - val_mean_squared_error: 0.0041
# Epoch 34/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0036 - val_mean_squared_error: 0.0036
# Epoch 35/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0039 - mean_squared_error: 0.0039 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 36/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0076 - mean_squared_error: 0.0076 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 37/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0026 - mean_squared_error: 0.0026 - val_loss: 7.4982e-04 - val_mean_squared_error: 7.4982e-04
# Epoch 38/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0049 - mean_squared_error: 0.0049 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 39/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0048 - mean_squared_error: 0.0048 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 40/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0032 - mean_squared_error: 0.0032 - val_loss: 0.0046 - val_mean_squared_error: 0.0046
# Epoch 41/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0036 - mean_squared_error: 0.0036 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 42/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0066 - mean_squared_error: 0.0066 - val_loss: 0.0067 - val_mean_squared_error: 0.0067
# Epoch 43/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0045 - mean_squared_error: 0.0045 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 44/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 45/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 5.2589e-04 - val_mean_squared_error: 5.2589e-04
# Epoch 46/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 7.3042e-04 - val_mean_squared_error: 7.3042e-04
# Epoch 47/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0027 - mean_squared_error: 0.0027 - val_loss: 8.8891e-04 - val_mean_squared_error: 8.8891e-04
# Epoch 48/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0125 - mean_squared_error: 0.0125 - val_loss: 0.0040 - val_mean_squared_error: 0.0040
# Epoch 49/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0051 - mean_squared_error: 0.0051 - val_loss: 0.0018 - val_mean_squared_error: 0.0018
# Epoch 50/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 6.3028e-04 - val_mean_squared_error: 6.3028e-04
# Epoch 51/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0050 - mean_squared_error: 0.0050 - val_loss: 7.5796e-04 - val_mean_squared_error: 7.5796e-04
# Epoch 52/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 53/55
# 8379/8379 [==============================] - 17s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0034 - val_mean_squared_error: 0.0034
# Epoch 54/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0035 - mean_squared_error: 0.0035 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 55/55
# 8379/8379 [==============================] - 18s 2ms/step - loss: 0.0038 - mean_squared_error: 0.0038 - val_loss: 5.9108e-04 - val_mean_squared_error: 5.9108e-04

# %%
predict = AE_2.predict(valid)

# %%
latent_dim=10

# %%
style_list=['dark_background']
# Plot a demonstration figure for every available style sheet.

fig, ax = plt.subplots(5,4, figsize=(20,15))
ax = ax.flatten()
for nn, ii in enumerate(np.arange(20)):
    if ii<16:
        jj = 0
    else:
        jj = 1
    ind = np.where(np.array(valid_['new_inf_labels'])==(nn%16))
    
    #print(ind)
    ax[nn].plot(valid[ind][jj], color='k')
    ax[nn].plot(valid[ind][jj], color='orange', ls='--',alpha=0.75)
    if nn in [16,17,18,19]:
        ax[ii].set_xlabel(r'restframe $\lambda$ [nm]')
    if ii%4==0:
        ax[ii].set_ylabel(r'standardized flux')    
plt.tight_layout()
# plt.savefig(os.path.join(plotpath,'reconstructions_test_AE2.pdf'), bbox_inches='tight')
# plt.show()

# %%
wlmin, wlmax    = (3388,8318)
wl_range      = (np.log10(wlmin),np.log10(wlmax))
# new binning 
new_wl        = np.logspace(wl_range[0],wl_range[1],fixed_num_bins+1)

# %%
loss = np.mean((valid-predict)**2,axis=0)

# %%
plt.plot(new_wl[:-1],loss,color='navy')
plt.xlabel(r'restframe $\lambda$ [nm]')
plt.ylabel('mean reconstruction error')
plt.grid()
plt.tight_layout()
#plt.savefig(os.path.join(plotpath,'mean_reconstruction_error_AE2.pdf'), bbox_inches='tight')

# %%
# path = os.path.join(root_models,'full_ae_model_%s_run%s_denoised_inpainted_2'%(label_2,RUN))
# AE_2.save(path)

# %%
print(path)
# Out:
# /global/cscratch1/sd/vboehm/Models/SDSS_AE/decoder_galaxies_quasars_bins1000_wl3388-8318_minz005_maxz036_minSN50_10_fully_connected_mean_div_run1_new

# %%
def extract_layers(main_model, starting_layer_ix, ending_layer_ix):
    new_model = Sequential()
    for ix in range(starting_layer_ix, ending_layer_ix):
        curr_layer = main_model.get_layer(index=ix)
        print(ix, curr_layer)
        new_model.add(curr_layer)
    return new_model

# %%
encoder = extract_layers(AE_2,0,2)
encoder.build((None,fixed_num_bins,1))
encoder.summary()
# Out:
# 0 <tensorflow.python.keras.engine.input_layer.InputLayer object at 0x2aaaaede8640>
# 1 <tensorflow.python.keras.engine.sequential.Sequential object at 0x2aabdb1852b0>
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential (Sequential)      (None, 10, 1)             1597500
# =================================================================
# Total params: 1,597,500
# Trainable params: 1,597,500
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_valid = encoder.predict(valid)
encoded_train = encoder.predict(train)

# %%
# path = os.path.join(root_encoded,'encoder_%(label_2, RUN))
# encoder.save(path)

# %%
encoded_valid = np.squeeze(encoded_valid)
encoded_train = np.squeeze(encoded_train)
print(len(encoded_valid))
np.save(os.path.join(data_path,'encoded_AE2_RUN%s_2.npy'%(RUN)),[encoded_train, encoded_valid])
# Out:
# 139642

# %%
print(data_path)
# Out:
# /global/cscratch1/sd/vboehm/SDSSOutlier/fc

# %%
lims = 50

fig, ax = plt.subplots(2,latent_dim//2, figsize=(20,6))
ax=ax.flatten()
for ii in range(latent_dim):
    jj= (ii+1)%latent_dim
    im = ax[ii].scatter(encoded_valid[:,ii],encoded_valid[:,jj],c=valid_['z'], cmap='jet',s=4)
    ax[ii].set_xlim(max(min(encoded_valid[:,ii]),-lims),min(max(encoded_valid[:,ii]),lims))
    ax[ii].set_ylim(max(min(encoded_valid[:,jj]),-lims),min(max(encoded_valid[:,jj]),lims))
    ax[ii].set_xlabel('dim %d'%ii)
    ax[ii].set_ylabel('dim %d'%jj)
    plt.colorbar(im, ax=ax[ii])
plt.tight_layout()
plt.savefig(os.path.join(plotpath,'encoded_redshift_AE2.pdf'), bbox_inches='tight')
plt.show()

# %%
lims = 50

fig, ax = plt.subplots(2,latent_dim//2, figsize=(20,6))
ax=ax.flatten()
for ii in range(latent_dim):
    jj= (ii+1)%latent_dim
    im = ax[ii].scatter(encoded_valid[:,ii],encoded_valid[:,jj],c=valid_['subclass'], cmap='Paired', s=4)
    ax[ii].set_xlim(max(min(encoded_valid[:,ii]),-lims),min(max(encoded_valid[:,ii]),lims))
    ax[ii].set_ylim(max(min(encoded_valid[:,jj]),-lims),min(max(encoded_valid[:,jj]),lims))
    ax[ii].set_xlabel('dim %d'%ii)
    ax[ii].set_ylabel('dim %d'%jj)
    plt.colorbar(im, ax=ax[ii])
plt.tight_layout()
plt.savefig(os.path.join(plotpath,'encoded_subclass_AE2.pdf'), bbox_inches='tight')
plt.show()

# %%
from tensorflow import keras

AE_2 = keras.models.load_model(os.path.join(root_models,'full_ae_model_%s_run%s_denoised_inpainted'%(label_2,RUN)))

# %%
decoder = extract_layers(AE_2,2,3)
decoder.build(input_shape=(None,10,1))
decoder.summary()
# Out:
# 2 <tensorflow.python.keras.engine.sequential.Sequential object at 0x2aac4326d4f0>
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# sequential_1 (Sequential)    (None, 1000)              1598490
# =================================================================
# Total params: 1,598,490
# Trainable params: 1,598,490
# Non-trainable params: 0
# _________________________________________________________________

# %%
encoded_train, encoded_valid, encoded_test = np.load(os.path.join(root_encoded,'encoded_AE2_%s_RUN%s.npy'%(label_2,RUN)), allow_pickle=True)

# %%
x, logps = np.load('optimization_results.npy', allow_pickle=True)

logps=np.asarray(logps).reshape((5,16))

x=np.asarray(x).reshape((5,15,10,1))
print(x.shape)

for ii in range(5):
    plt.plot(decoder(x[ii,0:1]).numpy()[0],color='navy',label='logp=%.1f'%-logps[ii,0])
    plt.plot(decoder(x[ii,-1::]).numpy()[0],alpha=0.8,color='gold',label='logp=%.1f'%-logps[ii,-1])
    plt.legend()
    plt.show()
# Out:
# (5, 15, 10, 1)

# %%
x, logps = np.load('optimization_results_long.npy', allow_pickle=True)

logps=np.asarray(logps).reshape((2,31))

x=np.asarray(x).reshape((2,30,10,1))
print(x.shape)

for ii in range(2):
    plt.plot(decoder(x[ii,0:1]).numpy()[0],color='navy',label='logp=%.1f'%-logps[ii,0])
    plt.plot(decoder(x[ii,-1::]).numpy()[0],alpha=0.8,color='gold',label='logp=%.1f'%-logps[ii,-1])
    plt.legend()
    plt.show()
# Out:
# (2, 30, 10, 1)

# %%
path = os.path.join(root_decoded,'decoder_AE2_%s_run%s_inpainted_denoised'%(label_2, RUN))
decoder.save(path)
# Out:
# WARNING:tensorflow:From /global/homes/v/vboehm/.conda/envs/tf22/lib/python3.8/site-packages/tensorflow/python/ops/resource_variable_ops.py:1813: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# INFO:tensorflow:Assets written to: /global/cscratch1/sd/vboehm/Datasets/decoded/sdss/decoder_AE2_galaxies_quasars_bins1000_wl3388-8318_minz005_maxz036_minSN50_10_fully_connected_mean_div_run1_inpainted_denoised/assets

# %%
decoded_train = AE_2.predict(train)
decoded_valid = AE_2.predict(valid)
decoded_test  = AE_2.predict(test)

# %%
np.save(os.path.join(root_decoded,'decoded_AE2_%s.npy'%(label_2)),[decoded_train,decoded_valid, decoded_test, mean, std])

# %%
label_2
# Out:
# 'galaxies_quasars_bins1000_wl3388-8318_minz005_maxz036_minSN50_10_fully_connected_mean_div'
